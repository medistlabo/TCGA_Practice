# %% [markdown]
# <a href="https://colab.research.google.com/github/medistlabo/TCGA_Practice/blob/main/tcga_practice_day19_cox.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install lifelines
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.1/409.1 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.3/117.3 kB 7.4 MB/s eta 0:00:00
# ...
#   Created wheel for autograd-gamma: filename=autograd_gamma-0.5.0-py3-none-any.whl size=4030 sha256=a7d7ac31911b0a6e375104711d6dddd29fae0aab03e795bc193d89d62485b03a
#   Stored in directory: /root/.cache/pip/wheels/50/37/21/0a719b9d89c635e89ff24bd93b862882ad675279552013b2fb
# Successfully built autograd-gamma
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from lifelines import CoxPHFitter

# %%
data = {
    "patient": ["P1","P2","P3","P4","P5","P6","P7","P8","P9","P10",
                "P11","P12","P13","P14","P15","P16"],

    "expression": [5,12,18,25,30,7,40,22,15,35,28,10,45,8,33,20],

    "survival_month": [50,40,35,20,15,45,10,25,38,12,18,48,8,52,14,28],

    "status": [0,0,1,1,1,0,1,1,0,1,1,0,1,0,1,1]
}

df = pd.DataFrame(data)

df
# Out:
#    patient  expression  survival_month  status
# 0       P1           5              50       0
# 1       P2          12              40       0
# 2       P3          18              35       1
# 3       P4          25              20       1
# 4       P5          30              15       1
# 5       P6           7              45       0
# 6       P7          40              10       1
# 7       P8          22              25       1
# 8       P9          15              38       0
# 9      P10          35              12       1
# 10     P11          28              18       1
# 11     P12          10              48       0
# 12     P13          45               8       1
# 13     P14           8              52       0
# 14     P15          33              14       1
# 15     P16          20              28       1

# %%
cox = CoxPHFitter()
df_cox = df.drop(columns = ["patient"])
df_cox
# Out:
#     expression  survival_month  status
# 0            5              50       0
# 1           12              40       0
# 2           18              35       1
# 3           25              20       1
# 4           30              15       1
# 5            7              45       0
# 6           40              10       1
# 7           22              25       1
# 8           15              38       0
# 9           35              12       1
# 10          28              18       1
# 11          10              48       0
# 12          45               8       1
# 13           8              52       0
# 14          33              14       1
# 15          20              28       1

# %%
cox.fit(
    df_cox,
    duration_col = "survival_month",
    event_col = "status",
)
# Out:
# /usr/local/lib/python3.12/dist-packages/lifelines/fitters/coxph_fitter.py:1614: ConvergenceWarning: Newton-Raphson failed to converge sufficiently. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-model
#   warnings.warn(
# <lifelines.CoxPHFitter: fitted with 16 total observations, 6 right-censored observations>

# %%
cox.print_summary()
# Out:
# <lifelines.CoxPHFitter: fitted with 16 total observations, 6 right-censored observations>
#              duration col = 'survival_month'
#                 event col = 'status'
#       baseline estimation = breslow
#    number of observations = 16
# number of events observed = 10
#    partial log-likelihood = -0.21
#          time fit was run = 2026-05-29 00:23:04 UTC
#
# ---
#             coef exp(coef)  se(coef)  coef lower 95%  coef upper 95% exp(coef) lower 95% exp(coef) upper 95%
# covariate
# expression  1.56      4.76      0.96           -0.32            3.45                0.72               31.37
#
#             cmp to    z    p  -log2(p)
# covariate
# expression    0.00 1.62 0.10      3.26
# ---
# Concordance = 1.00
# Partial AIC = 2.43
# log-likelihood ratio test = 47.76 on 1 df
# -log2(p) of ll-ratio test = 37.59
