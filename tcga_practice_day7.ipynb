# %% [markdown]
# <a href="https://colab.research.google.com/github/medistlabo/TCGA_Practice/blob/main/tcga_practice_day7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "gene": ["TP53", "EGFR", "KRAS", "MYC", "BRAF", "PIK3CA", "ALK", "PTEN"],
    "expression": [12.5, 30.1, 18.2, 25.4, 40.2, 15.3, 28.4, 9.8],
    "survival": [24, 12, 36, 18, 10, 30, 14, 40],
    "group": ["High", "Low", "High", "Low", "Low", "High", "Low", "High"]
}

df = pd.DataFrame(data)

df
# Out:
#      gene  expression  survival group
# 0    TP53        12.5        24  High
# 1    EGFR        30.1        12   Low
# 2    KRAS        18.2        36  High
# 3     MYC        25.4        18   Low
# 4    BRAF        40.2        10   Low
# 5  PIK3CA        15.3        30  High
# 6     ALK        28.4        14   Low
# 7    PTEN         9.8        40  High

# %%
df[df["expression"] > 20import pandas as pd
import matplotlib.pyplot as plt

data = {
    "gene": ["TP53", "EGFR", "KRAS", "MYC", "BRAF", "PIK3CA", "ALK", "PTEN"],
    "expression": [12.5, 30.1, 18.2, 25.4, 40.2, 15.3, 28.4, 9.8],
    "survival": [24, 12, 36, 18, 10, 30, 14, 40],
    "group": ["High", "Low", "High", "Low", "Low", "High", "Low", "High"]
}

df = pd.DataFrame(data)

df]
# Out:
#    gene  expression  survival group
# 1  EGFR        30.1        12   Low
# 3   MYC        25.4        18   Low
# 4  BRAF        40.2        10   Low
# 6   ALK        28.4        14   Low

# %%
df[df["survival"] > 20]
# Out:
#      gene  expression  survival group
# 0    TP53        12.5        24  High
# 2    KRAS        18.2        36  High
# 5  PIK3CA        15.3        30  High
# 7    PTEN         9.8        40  High

# %%
df[(df["expression"] > 15) & (df["survival"] > 20)]
# Out:
#      gene  expression  survival group
# 2    KRAS        18.2        36  High
# 5  PIK3CA        15.3        30  High

# %%
df.groupby("group")[["expression" , "survival"]].mean()
# Out:
#        expression  survival
# group
# High       13.950      32.5
# Low        31.025      13.5

# %%
df["group"].value_counts()
# Out:
# group
# High    4
# Low     4
# Name: count, dtype: int64

# %%
plt.hist(df["expression"])

plt.xlabel("expression")
plt.ylabel("count")

plt.show()

# %%
df.boxplot(column = "expression", by = "group")

plt.show()

# %%
plt.scatter(df["expression"], df["survival"])

plt.xlabel("expression")
plt.ylabel("survival")

plt.show()

# %%
df["expression"].corr(df["survival"])
# Out:
# np.float64(-0.8689058752257652)
