# %% [markdown]
# <a href="https://colab.research.google.com/github/medistlabo/TCGA_Practice/blob/main/tcga_practice_day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "gene": ["TP53", "EGFR", "KRAS", "MYC"],
    "expression": [12.5, 30.1, 18.2, 25.4],
    "group": ["High", "Low", "High", "Low"]
}

df = pd.DataFrame(data)

df
# Out:
#    gene  expression group
# 0  TP53        12.5  High
# 1  EGFR        30.1   Low
# 2  KRAS        18.2  High
# 3   MYC        25.4   Low

# %%
df.to_csv("gene_expression.csv")

# %%
new_df = pd.read_csv("gene_expression.csv")
new_df.head()
# Out:
#    Unnamed: 0  gene  expression group
# 0           0  TP53        12.5  High
# 1           1  EGFR        30.1   Low
# 2           2  KRAS        18.2  High
# 3           3   MYC        25.4   Low

# %%
df.sort_values("expression")
# Out:
#    gene  expression group
# 0  TP53        12.5  High
# 2  KRAS        18.2  High
# 3   MYC        25.4   Low
# 1  EGFR        30.1   Low

# %%
df.sort_values("expression" , ascending=False)
# Out:
#    gene  expression group
# 1  EGFR        30.1   Low
# 3   MYC        25.4   Low
# 2  KRAS        18.2  High
# 0  TP53        12.5  High

# %%
df.describe().T
# Out:
#             count   mean       std   min     25%   50%     75%   max
# expression    4.0  21.55  7.768526  12.5  16.775  21.8  26.575  30.1

# %%
import matplotlib.pyplot as plt
plt.bar(df["gene"], df["expression"])
plt.show()

# %%
high_df = df[df["group"] == "High"]
high_df
# Out:
#    gene  expression group
# 0  TP53        12.5  High
# 2  KRAS        18.2  High

# %%
df[df["expression"] > 20]
# Out:
#    gene  expression group
# 1  EGFR        30.1   Low
# 3   MYC        25.4   Low

# %%
df[(df["expression" ] > 15) & (df["group"] == "Low")]
# Out:
#    gene  expression group
# 1  EGFR        30.1   Low
# 3   MYC        25.4   Low

# %%
df["group"].unique()
# Out:
# array(['High', 'Low'], dtype=object)

# %%
df["group"].value_counts()
# Out:
# group
# High    2
# Low     2
# Name: count, dtype: int64
