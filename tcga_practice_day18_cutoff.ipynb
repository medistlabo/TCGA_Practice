# %% [markdown]
# <a href="https://colab.research.google.com/github/medistlabo/TCGA_Practice/blob/main/tcga_practice_day18_cutoff.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install lifelines

# %%
import pandas as pd
import matplotlib.pyplot as plt
from lifelines import KaplanMeierFitter
from lifelines.statistics import logrank_test

# %%
data = {
    "patient": ["P1","P2","P3","P4","P5","P6","P7","P8","P9","P10",
                "P11","P12","P13","P14","P15","P16"],

    "expression": [5,12,18,25,30,7,40,22,15,35,28,10,45,8,33,20],

    "survival_month": [50,40,35,20,15,45,10,25,38,12,18,48,8,52,14,28],

    "status": [0,0,1,1,1,0,1,1,0,1,1,0,1,0,1,1]
}

df = pd.DataFrame(data)

# %%
df["group_median"] = df["expression"].apply(
    lambda x:"High"
    if x >= df["expression"].median()
    else "Low"
)

# %%
high_median = df[df["group_median"] == "High"]
low_median = df[df["group_median"] == "Low"]

# %%
results_median = logrank_test(
    high_median["survival_month"],
    low_median["survival_month"],
    event_observed_A = high_median["status"],
    event_observed_B = low_median["status"]
)

results_median.print_summary()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <tbody>
#     <tr>
#       <th>t_0</th>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>null_distribution</th>
#       <td>chi squared</td>
#     </tr>
#     <tr>
#       <th>degrees_of_freedom</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>test_name</th>
#       <td>logrank_test</td>
#     </tr>
#   </tbody>
# </table>
# </div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>test_statistic</th>
#       <th>p</th>
#       <th>-log2(p)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>16.94</td>
#       <td>&lt;0.005</td>
#       <td>14.66</td>
#     </tr>
#   </tbody>
# ...

# %%
df["group_30"] = df["expression"].apply(
    lambda x: "High"
    if x >= 30
    else "Low"
)

# %%
high_30 = df[df["group_30"] == "High"]
low_30 = df[df["group_30"] == "Low"]

# %%
df["group_30"].value_counts()
# Out:
# group_30
# Low     11
# High     5
# Name: count, dtype: int64

# %%
results_30 = logrank_test(
    high_30["survival_month"],
    low_30["survival_month"],
    event_observed_A=high_30["status"],
    event_observed_B=low_30["status"]
)

results_30.print_summary()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <tbody>
#     <tr>
#       <th>t_0</th>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>null_distribution</th>
#       <td>chi squared</td>
#     </tr>
#     <tr>
#       <th>degrees_of_freedom</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>test_name</th>
#       <td>logrank_test</td>
#     </tr>
#   </tbody>
# </table>
# </div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>test_statistic</th>
#       <th>p</th>
#       <th>-log2(p)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>20.06</td>
#       <td>&lt;0.005</td>
#       <td>17.03</td>
#     </tr>
#   </tbody>
# ...

# %%
df.groupby("group_median")["status"].mean()

df.groupby("group_30")["status"].mean()
# Out:
# group_30
# High    1.000000
# Low     0.454545
# Name: status, dtype: float64
